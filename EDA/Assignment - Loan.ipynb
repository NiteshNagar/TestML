# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loan=pd.read_excel("loan_sanction.xlsx")
loan
# Out:
#       Sr   Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0      0  LP001015   Male     Yes          0      Graduate            No
# 1      1  LP001022   Male     Yes          1      Graduate            No
# 2      2  LP001031   Male     Yes          2      Graduate            No
# 3      3  LP001035   Male     Yes          2      Graduate            No
# 4      4  LP001051   Male      No          0  Not Graduate            No
# ..   ...       ...    ...     ...        ...           ...           ...
# 364  364  LP002980   Male      No          0      Graduate            No
# 365  365  LP002986   Male     Yes          0      Graduate            No
# 366  366  LP002989   Male      No          0      Graduate           Yes
# 367  367  LP001035   Male     Yes          2      Graduate            No
# 368  368  LP001035   Male     Yes          2      Graduate           NaN
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan.columns  # shows the column headings
# Out:
# Index(['Sr', 'Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
loan.shape
# Out:
# (368, 13)

# %%
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 368 entries, 0 to 367
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr                 368 non-null    int64
#  1   Loan_ID            368 non-null    object
#  2   Gender             368 non-null    object
#  3   Married            368 non-null    object
#  4   Dependents         358 non-null    object
#  5   Education          368 non-null    object
#  6   Self_Employed      368 non-null    object
#  7   ApplicantIncome    368 non-null    int64
#  8   CoapplicantIncome  368 non-null    int64
#  9   LoanAmount         368 non-null    int64
#  10  Loan_Amount_Term   368 non-null    int64
#  11  Credit_History     368 non-null    int64
#  12  Property_Area      368 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 37.5+ KB

# %%
loan.dtypes
# Out:
# Sr                    int64
# Loan_ID              object
# Gender               object
# Married              object
# Dependents           object
# Education            object
# Self_Employed        object
# ApplicantIncome       int64
# CoapplicantIncome     int64
# LoanAmount            int64
# Loan_Amount_Term      int64
# Credit_History        int64
# Property_Area        object
# dtype: object

# %%
loan.describe()
# Out:
#                Sr  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  368.000000       368.000000         368.000000  368.000000
# mean   183.500000      4798.899457        1572.230978  135.883152
# std    106.376689      4905.674532        2331.605418   60.905519
# min      0.000000         0.000000           0.000000   28.000000
# 25%     91.750000      2859.500000           0.000000  100.750000
# 50%    183.500000      3785.500000        1054.000000  125.000000
# 75%    275.250000      5059.000000        2447.500000  157.250000
# max    367.000000     72529.000000       24000.000000  550.000000
#
#        Loan_Amount_Term  Credit_History
# count        368.000000           368.0
# mean         342.869565             1.0
# std           64.576460             0.0
# min            6.000000             1.0
# 25%          360.000000             1.0
# 50%          360.000000             1.0
# 75%          360.000000             1.0
# max          480.000000             1.0

# %%
loan.tail(10)
# Out:
#       Sr   Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 358  358  LP002954    Male     Yes          2  Not Graduate            No
# 359  359  LP002962    Male      No          0      Graduate            No
# 360  360  LP002965  Female     Yes          0      Graduate            No
# 361  361  LP002969    Male     Yes          1      Graduate            No
# 362  362  LP002971    Male     Yes         3+  Not Graduate           Yes
# 363  363  LP002975    Male     Yes          0      Graduate            No
# 364  364  LP002980    Male      No          0      Graduate            No
# 365  365  LP002986    Male     Yes          0      Graduate            No
# 366  366  LP002989    Male      No          0      Graduate           Yes
# 367  367  LP001035    Male     Yes          2      Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 358             3132                  0          76               360
# ...

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q1. Check how many duplicate rows are present.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

loan=pd.read_excel("loan_sanction.xlsx")

loan = loan.drop (['Sr'],axis=1)
loan = loan[['Loan_ID','ApplicantIncome']]
duplicate_rows = loan[loan.duplicated(keep=False)]

if not duplicate_rows.empty:
    print("Duplicate rows:", len(duplicate_rows))
    print(duplicate_rows)
else:
    print("No duplicate rows found.")
# Out:
# Duplicate rows: 2
#       Loan_ID  ApplicantIncome
# 3    LP001035             2340
# 367  LP001035             2340

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# q2. If any Duplicates Present, drop those duplicates

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

loan=pd.read_excel("loan_sanction.xlsx")

loan = loan.drop (['Sr'],axis=1)
loan = loan[['Loan_ID','ApplicantIncome']]

drop_duplicates = loan.drop_duplicates(keep='first')
drop_duplicates.tail(5)
# Out:
#       Loan_ID  ApplicantIncome
# 362  LP002971             4009
# 363  LP002975             4158
# 364  LP002980             3250
# 365  LP002986             5000
# 366  LP002989             9200

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q3. Check null values in each column

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

loan=pd.read_excel("loan_sanction.xlsx")
loan.isnull().sum()
# Out:
# Sr                    0
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           10
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %% [markdown]
# --------------------------------------------------------------------------------------------------

# %% [markdown]
# Q4. Delete the Rows which are having null values.

# %%
import pandas as pd
loan=pd.read_excel("loan_sanction.xlsx")

df = pd.DataFrame(loan)
df_cleaned = df.dropna()

print(df_cleaned[['Loan_ID','ApplicantIncome']])
# Out:
#       Loan_ID  ApplicantIncome
# 0    LP001015             5720
# 1    LP001022             3076
# 2    LP001031             5000
# 3    LP001035             2340
# 4    LP001051             3276
# ..        ...              ...
# 363  LP002975             4158
# 364  LP002980             3250
# 365  LP002986             5000
# 366  LP002989             9200
# 367  LP001035             2340
#
# [358 rows x 2 columns]

# %% [markdown]
# Q17. Print number of unique values in Gender column.

# %%
import pandas as pd
loan=pd.read_excel("loan_sanction.xlsx")

df = pd.DataFrame(loan)
num_unique_genders = df['Gender'].nunique()

print("Number of unique values in the 'Gender' column:", num_unique_genders)
# Out:
# Number of unique values in the 'Gender' column: 2
