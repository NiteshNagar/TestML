# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ipl=pd.read_csv("IPL_Dataset.csv")
ipl
# Out:
#      POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1           KL Rahul   14    14   2   670  132*  55.83  518  129.34
# 1      2     Shikhar Dhawan   17    17   3   618  106*  44.14  427  144.73
# 2      3       David Warner   16    16   2   548   85*  39.14  407  134.64
# 3      4       Shreyas Iyer   17    17   2   519   88*  34.60  421  123.27
# 4      5       Ishan Kishan   14    13   4   516    99  57.33  354  145.76
# ..   ...                ...  ...   ...  ..   ...   ...    ...  ...     ...
# 128  129      Khaleel Ahmed    7     1   0     0    0*   0.00    2    0.00
# 129  130     Arshdeep Singh    8     1   0     0    0*   0.00    3    0.00
# 130  131        Daniel Sams    3     1   0     0    0*   0.00    2    0.00
# 131  132  Shreevats Goswami    2     2   0     0    0*   0.00    4    0.00
# 132  133        Trent Boult   15     1   0     0    0*   0.00    1    0.00
#
#      100  50  4s  6s
# 0      1   5  58  23
# 1      2   4  67  12
# ...

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q1. What is the maximum number of matches played by an individual player in a season?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ipl=pd.read_csv("IPL_Dataset.csv")

max_val = ipl['Mat'].max();
max_row = ipl[ipl['Mat'] == max_val]
List_Player = max_row[['Player','Mat']]
print("Maximum number of matches played by an individual player in a season =", max_val)
print("List of the players with maximun", max_val, "no of matches")
print(List_Player)
# Out:
# Maximum number of matches played by an individual player in a season = 17
# List of the players with maximun 17 no of matches
#             Player  Mat
# 1   Shikhar Dhawan   17
# 3     Shreyas Iyer   17
# 19  Marcus Stoinis   17
# 67   Kagiso Rabada   17

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q2. What is the highest average of a player in a season?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

max_Avg2 = ipl['Avg'].max();
max_AvgtoInt = int(max_Avg2)
max_row = ipl[ipl['Avg'] == max_AvgtoInt]
highestAvgPlayer = max_row['Player']
print(highestAvgPlayer, "is the player with higest average  with ", max_AvgtoInt)
# Out:
# 57    Deepak Hooda
# Name: Player, dtype: object is the player with higest average  with  101

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q3. What is the average number of matches played by the players in a season?

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q4. Please check the correlation between all the features.

# %% [markdown]
# First Approach

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")
ipl.columns
# Out:
# Index(['POS', 'Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Avg', 'BF', 'SR',
#        '100', '50', '4s', '6s'],
#       dtype='object')

# %%
Ipl_upd= ipl.drop (['POS','Player'],axis=1)
plt.figure(figsize=(10,5))
sns.heatmap(Ipl_upd.corr(),cmap='YlOrBr')
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_7060\2142325217.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(Ipl_upd.corr(),cmap='YlOrBr')
# <Axes: >

# %% [markdown]
# Second Approach

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")
ipl.columns
# Out:
# Index(['POS', 'Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Avg', 'BF', 'SR',
#        '100', '50', '4s', '6s'],
#       dtype='object')

# %%
ipl.dtypes
# Out:
# POS         int64
# Player     object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS         object
# Avg       float64
# BF          int64
# SR        float64
# 100         int64
# 50          int64
# 4s          int64
# 6s          int64
# dtype: object

# %%
ipl['HS'] = ipl['HS'].str.extract('(\d+)').astype(int)

# %%
ipl.dtypes
# Out:
# POS         int64
# Player     object
# Mat         int64
# Inns        int64
# NO          int64
# Runs        int64
# HS          int32
# Avg       float64
# BF          int64
# SR        float64
# 100         int64
# 50          int64
# 4s          int64
# 6s          int64
# dtype: object

# %%
Ipl_upd= ipl.drop (['POS'],axis=1)
num_col = [fea for fea in Ipl_upd.columns if Ipl_upd[fea].dtypes !='object']
numeric_data = Ipl_upd[num_col]
numeric_data.corr()
# Out:
#            Mat      Inns        NO      Runs        HS       Avg        BF  \
# Mat   1.000000  0.728358  0.555261  0.565237  0.456171  0.306128  0.555102
# Inns  0.728358  1.000000  0.464356  0.895914  0.832002  0.585148  0.889753
# NO    0.555261  0.464356  1.000000  0.308747  0.235613  0.429888  0.271021
# Runs  0.565237  0.895914  0.308747  1.000000  0.913250  0.687475  0.989948
# HS    0.456171  0.832002  0.235613  0.913250  1.000000  0.774646  0.904798
# Avg   0.306128  0.585148  0.429888  0.687475  0.774646  1.000000  0.664173
# BF    0.555102  0.889753  0.271021  0.989948  0.904798  0.664173  1.000000
# SR    0.371328  0.581468  0.415060  0.517678  0.608398  0.591306  0.474226
# 100   0.128405  0.224328  0.019726  0.382577  0.383540  0.233726  0.358550
# 50    0.455437  0.755027  0.174184  0.912264  0.841283  0.638326  0.900547
# 4s    0.522628  0.846749  0.204779  0.959576  0.875322  0.623643  0.955994
# ...

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q5. Check the list of players who has an average greater than 50 as well strike rate above 120.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

Avg_Condition = ipl[ipl['Avg'] > 50] 
SR_Rate = ipl[ipl['SR'] > 120]

common_players = Avg_Condition[Avg_Condition.isin(SR_Rate)]
common_players[['Player','SR', 'Avg']]
#SR_Rate['Player']
#Avg_Condition['Player']
# Out:
#              Player      SR     Avg
# 0          KL Rahul  129.34   55.83
# 4      Ishan Kishan  145.76   57.33
# 31   Kieron Pollard  191.42   53.60
# 36  Wriddhiman Saha  139.86   71.33
# 37  Ruturaj Gaikwad  120.71   51.00
# 57     Deepak Hooda  142.25  101.00
# 60       Tom Curran  133.87   83.00

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q6. Please check the list of players who has an average greater than 40 and balls faced above 100.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

iplAvg_Condition = ipl[ipl['Avg'] > 40] 
BF_Condition = ipl[ipl['BF'] > 100]

avg_players = Avg_Condition['Player']
bf_players = BF_Condition['Player']
common_players = avg_players[avg_players.isin(bf_players)]

print("Player with average greater than 40 and balls faced above 100 are " )
print(common_players)
# Out:
# Player with average greater than 40 and balls faced above 100 are
# 0            KL Rahul
# 4        Ishan Kishan
# 9      AB de Villiers
# 24    Kane Williamson
# 31     Kieron Pollard
# 33    Ravindra Jadeja
# 36    Wriddhiman Saha
# 37    Ruturaj Gaikwad
# Name: Player, dtype: object

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q7. Please check the list of players who scored more than 300 runs with an average greater than 45 & strike rate above 130.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

Avg_Condition = ipl[ipl['Avg'] > 45] 
SR_Condition = ipl[ipl['SR'] > 130]
Run_Condition = ipl[ipl['Runs'] > 300]

avg_players = Avg_Condition[['Player','Runs', 'Avg', 'BF']]
sr_players = SR_Condition[['Player','Runs', 'Avg', 'BF']]
run_players = Run_Condition[['Player','Runs', 'Avg', 'BF']]

common_players1 = avg_players[avg_players.isin(sr_players)]
common_players2 = common_players1[common_players1.isin(run_players)]

common_players3 = common_players2.dropna(axis=0)
common_players3
# Out:
#              Player   Runs    Avg     BF
# 4      Ishan Kishan  516.0  57.33  354.0
# 9    AB de Villiers  454.0  45.40  286.0
# 24  Kane Williamson  317.0  45.28  237.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

Avg_Condition = ipl[ipl['Avg'] > 45] 
BF_Condition = ipl[ipl['SR'] > 130]
Run_Condition = ipl[ipl['Runs'] > 300]

avg_players = Avg_Condition['Player']
bf_players = BF_Condition['Player']
run_players = Run_Condition['Player']

common_players1 = avg_players[avg_players.isin(bf_players)]
common_player2 = common_players1[common_players1.isin(run_players)]

print("players who scored more than 300 runs with an average greater than 45 & strike rate above 130 are " )
print(common_player2)
# Out:
# players who scored more than 300 runs with an average greater than 45 & strike rate above 130 are
# 4        Ishan Kishan
# 9      AB de Villiers
# 24    Kane Williamson
# Name: Player, dtype: object

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q8. Players who scroed alteast one century in this season.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

century = ipl[ipl['100'] > 0]
ListPlayer = century[['Player','100']]
print("Players scroed alteast one century in this seasons are")
print(ListPlayer)
# Out:
# Players scroed alteast one century in this seasons are
#             Player  100
# 0         KL Rahul    1
# 1   Shikhar Dhawan    2
# 13  Mayank Agarwal    1
# 28      Ben Stokes    1

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q9. Players who scored atleast 4 half centuries in this season.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

half_centuries = ipl[ipl['50'] > 3]
ListPlayer = half_centuries[['Player','50']]
print("Players cored atleast 4 half centuries in this season are")
print(ListPlayer)
# Out:
# Players cored atleast 4 half centuries in this season are
#               Player  50
# 0           KL Rahul   5
# 1     Shikhar Dhawan   4
# 2       David Warner   4
# 4       Ishan Kishan   4
# 5    Quinton de Kock   4
# 6   Suryakumar Yadav   4
# 7   Devdutt Padikkal   5
# 9     AB de Villiers   5
# 10    Faf du Plessis   4

# %% [markdown]
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# Q10. Check the list of players who hit more than 45 boundARIES and more than 10 sixes in this season.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

# Filter players with more than 45 boundaries and more than 10 sixes
filtered_players = ipl[(ipl['4s'] > 45) & (ipl['6s'] > 10)]

# Display the list of players who meet the conditions
print(filtered_players[['Player','6s','4s']])
# Out:
#              Player  6s  4s
# 0          KL Rahul  23  58
# 1    Shikhar Dhawan  12  67
# 2      David Warner  14  52
# 5   Quinton de Kock  22  46
# 6  Suryakumar Yadav  11  61

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q11. Plot a histogram of number of matches played in a season by players.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

# Plot histogram
plt.figure(figsize=(7, 5))  # size 
plt.hist(ipl['Mat'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Number of Matches Played')
plt.ylabel('Number of Players')
plt.title('Histogram of Matches Played by Players')
plt.grid(True)

#for i, player in enumerate(ipl['Player']):
   # plt.annotate(player, (ipl['BF'][i], ipl['Runs'][i]), textcoords="offset points", xytext=(0,10), ha='center')

plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q12. Plot the histogram of balls faced by players.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

# Plot histogram
plt.figure(figsize=(8, 5))  # size 
plt.hist(ipl['BF'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('No of Balls Faced')
plt.ylabel('Name of Players')
plt.title('Histogram of balls faced by players')
plt.grid(True)
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q13. Top 20 players with most runs in a season.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

Req_dataSet = ipl[['Player','Runs']]


sorted_data = Req_dataSet.sort_values(by='Runs', ascending=False).head(20)
print(sorted_data)
# Out:
#               Player  Runs
# 0           KL Rahul   670
# 1     Shikhar Dhawan   618
# 2       David Warner   548
# 3       Shreyas Iyer   519
# 4       Ishan Kishan   516
# 5    Quinton de Kock   503
# 6   Suryakumar Yadav   480
# 7   Devdutt Padikkal   473
# 8        Virat Kohli   466
# 9     AB de Villiers   454
# 10    Faf du Plessis   449
# 11      Shubman Gill   440
# 12     Manish Pandey   425
# 13    Mayank Agarwal   424
# 14       Eoin Morgan   418
# 15      Sanju Samson   375
# 16     Ambati Rayudu   359
# 17   Nicholas Pooran   353
# 18       Nitish Rana   352
# 19    Marcus Stoinis   352

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q14. Bar chart for top 20 players with best strike rate in a season.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
ipl=pd.read_csv("IPL_Dataset.csv")

Req_dataSet = ipl[['Player','SR']]
sorted_data = Req_dataSet.sort_values(by='SR', ascending=False).head(20)

# Create a bar chart
plt.figure(figsize=(12, 6))   
plt.bar(sorted_data['Player'], sorted_data['SR'])
plt.xlabel('Players')
plt.ylabel('Strike Rates')
plt.title('Top 20 Players with Best Strike Rates')
plt.xticks(rotation=80)
plt.tight_layout()

# Display the bar chart
plt.show()

# %% [markdown]
# ----------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q15. Top 30 players with highest number of sixes.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ipl = pd.read_csv("IPL_Dataset.csv")
Ipl_upd= ipl.drop (['POS', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Avg', 'BF', 'SR', '100', '50', '4s'], axis=1)
Ipl_upd= Ipl_upd.sort_values(by='6s', ascending=False).head(30)
Ipl_upd
# Out:
#               Player  6s
# 4       Ishan Kishan  30
# 15      Sanju Samson  26
# 29     Hardik Pandya  25
# 17   Nicholas Pooran  25
# 14       Eoin Morgan  24
# 9     AB de Villiers  23
# 27       Chris Gayle  23
# 0           KL Rahul  23
# 31    Kieron Pollard  22
# 5    Quinton de Kock  22
# 22      Rohit Sharma  19
# 12     Manish Pandey  18
# 32     Rahul Tewatia  17
# 3       Shreyas Iyer  16
# 23       Jos Buttler  16
# 19    Marcus Stoinis  16
# 13    Mayank Agarwal  15
# 10    Faf du Plessis  14
# 2       David Warner  14
# 20    Jonny Bairstow  13
# 26      Shane Watson  13
# 40        Sam Curran  12
# 18       Nitish Rana  12
# 16     Ambati Rayudu  12
# 41   Shimron Hetmyer  12
# 1     Shikhar Dhawan  12
# 8        Virat Kohli  11
# 33   Ravindra Jadeja  11
# 6   Suryakumar Yadav  11
# 24   Kane Williamson  10

# %% [markdown]
# -------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q16. Scatter plot of runs scored by a player v/s balls faced in a season.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ipl2 = pd.read_csv("IPL_Dataset.csv")
ipl = ipl2.head(10)
# Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(ipl['BF'], ipl['Runs'], color='blue', alpha=0.7)
plt.xlabel('Balls Faced')
plt.ylabel('Runs')
plt.title('Runs Scored vs Balls Faced')
plt.grid(True)

for i, player in enumerate(ipl['Player']):
    plt.annotate(player, (ipl['BF'][i], ipl['Runs'][i]), textcoords="offset points", xytext=(10,10), ha='center')

plt.tight_layout()

# Display the scatter plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

ipl2 = pd.read_csv("IPL_Dataset.csv")
ipl = ipl2.head(10)

# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(ipl['BF'], ipl['Runs'], color='blue', alpha=0.7)
plt.xlabel('Balls Faced')
plt.ylabel('Runs')
plt.title('Runs Scored vs Balls Faced')
plt.grid(True)

for i, player in enumerate(ipl['Player']):
    plt.annotate(player, (ipl['BF'][i], ipl['Runs'][i]), textcoords="offset points", xytext=(0,7), ha='center')

plt.tight_layout()

# Display the scatter plot
plt.show()

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Q17. KDE plot for averages on a season.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your DataFrame from the CSV file
ipl_data2 = pd.read_csv("IPL_Dataset.csv")

#ipl_data = ipl_data2.head(3)

# Create a KDE plot for averages
plt.figure(figsize=(10, 6))
sns.kdeplot(data=ipl_data, x='Avg', fill=True, color='blue')
plt.xlabel('Average')
plt.ylabel('Density')
plt.title('KDE Plot of Averages in a Season')
plt.grid(True)

#for i, row in ipl_data.iterrows():
  #plt.annotate(row['Player'], (row['Avg'], 0), textcoords="offset points", xytext=(0,7), ha='center')


plt.tight_layout()

# Display the KDE plot
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your DataFrame from the CSV file
ipl_data = pd.read_csv("IPL_Dataset.csv")

#ipl_data = ipl_data.head(10)

# Create a KDE plot for averages
plt.figure(figsize=(8, 6))
sns.kdeplot(data=ipl_data, x='Runs', fill=True, color='blue')
plt.xlabel('Average')
plt.ylabel('Density')
plt.title('KDE Plot of Averages in a Season')
plt.grid(True)

#for i, row in ipl_data.iterrows():
  #plt.annotate(row['Player'], (row['Avg'], 0), textcoords="offset points", xytext=(0,7), ha='center')


plt.tight_layout()

# Display the KDE plot
plt.show()
